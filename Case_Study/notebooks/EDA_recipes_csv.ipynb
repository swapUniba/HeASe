# %%
import requests
import pandas as pd
from io import BytesIO
from zipfile import ZipFile

def download_and_extract_csv(zip_url):
    # Download the ZIP file
    response = requests.get(zip_url)
    response.raise_for_status()  # This will raise an error if the download failed

    # Extract the CSV file
    with ZipFile(BytesIO(response.content)) as thezip:
        # Assuming there's only one CSV file in the zip
        with thezip.open(thezip.namelist()[0]) as thefile:
            df = pd.read_csv(thefile)

    return df

# %%
github_zip_url = 'https://gitlab.com/felix134/connected-recipe-data-set/-/raw/master/data/hummus_data/preprocessed/pp_recipes.zip'

# %%
dataframe = download_and_extract_csv(github_zip_url)
print(dataframe)
# Out:
# C:\Users\Utente\AppData\Local\Temp\ipykernel_1532\3235369919.py:15: DtypeWarning: Columns (35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(thefile)
#         Unnamed: 0  recipe_id                                 title  \
# 0                0     447642         Cranberry-Orange Caramel Corn
# 1                1      53662                 Cocktail De Camarones
# 2                2     520465        Inbal Jerusalem Hotel Snowball
# 3                3     213601         Santorini Roasted Leg of Lamb
# 4                4      67731             Cantonese Chicken Burgers
# ...            ...        ...                                   ...
# 507330      507330     161672                   Southern Belle Bars
# 507331      507331     242936                    Miriam's Egg Rolls
# 507332      507332      51384    Creamy Chicken and Chile Casserole
# 507333      507333     406042                             Won Ton's
# 507334      507334     131807  Whole Foods Mediterranean Tuna Salad
#
#                                               description   author_id  \
# 0       Taken from Beter Homes and Gardens, November 2...      409184
# 1       I ordered shrimp cocktail at a Mexican restaur...       64251
# 2       This recipe was created in response to a Janua...  1803632771
# 3       A succulent slow-roasted leg of lamb with herb...      183057
# 4       Adapted from a recipe in BHG's grilling magazine.       37779
# ...                                                   ...         ...
# 507330              Pecan pie in an easy bar cookie form.       53959
# 507331  My sister introduced me to homemade egg rolls ...      461724
# 507332  Yummy, creamy, fast, and easy! This could easi...       47175
# 507333  Great as Pot Stickers or in a soup of chicken ...      335392
# 507334  This is superb! I could eat buckets of this! T...        4439
#
#         duration                                         directions  \
# 0           40.0  ['Preheat oven to 275 degrees. In a very large...
# 1           20.0  ['After you chop the tomatoes, onions and cila...
# 2          210.0  ['Combine gelatin with cold water', 'Combine c...
# 3          375.0  ['Trim excess fat and silver skin from lamb le...
# 4           38.0  ['In a mixing bowl, add the egg, sesame oil, a...
# ...          ...                                                ...
# 507330      70.0  ['Heat oven to 350°F  ', 'Combine 1 1/4 cups f...
# 507331      50.0  ['Heat 2 tablespoons oil in wok or frying pan....
# 507332      40.0  ['Heat oven to 400°F.', 'Cook chicken over med...
# 507333      55.0  ['Combine all ingredients.', 'Place Won Ton wr...
# 507334      65.0  ['In a large bowl, combine the tuna, artichoke...
#
#                                               ingredients serves  \
# 0       {'': [('popcorn, popped', '12  time(s) cups ')...     20
# 1       {'': [('shelled and cooked shrimp (50-60 count...    2-4
# 2       {'': [('cream', '200  time(s) g '), ('vanilla ...      5
# 3       {'': [('of lamb', '6  time(s) lbs leg '), ('dr...  10-12
# 4       {'': [('egg, beaten', '1  time(s) '), ('toaste...      4
# ...                                                   ...    ...
# 507330  {'filling': [('dark corn syrup', '/ time(s) cu...    6-8
# 507331  {'': [('oil', '5  time(s) tablespoons '), ('gr...      5
# 507332  {'': [('boneless skinless chicken breasts, cub...    NaN
# 507333  {'': [('wonton wrappers (about 48)', '12  time...      6
# 507334  {'': [('chunk light tuna, drained well', '4 ti...    6-8
#
#        last_changed_date  ... sugars [g] protein [g] direction_size  \
# 0             2011-01-29  ...        6.9         0.8              9
# 1             2009-06-03  ...        6.3        51.3              7
# 2             2015-01-08  ...       78.0        87.7             12
# 3             2009-05-17  ...        3.6        51.1              8
# 4             2007-11-21  ...        4.2        30.3              6
# ...                  ...  ...        ...         ...            ...
# 507330        2021-07-20  ...       32.0         7.0              4
# 507331        2009-09-09  ...        6.5        29.5              8
# 507332        2012-04-07  ...       33.6       121.5             12
# 507333        2010-06-23  ...        0.3        19.4              7
# 507334        2013-01-31  ...        4.2        31.8              1
#
#         ingredients_sizes  who_score  fsa_score  nutri_score  \
# 0                       9   0.168254      0.000         0.00
# 1                      10   0.335455      0.625         0.25
# 2                      17   0.128082      0.000         0.00
# 3                       8   0.320622      0.375         0.00
# 4                      12   0.254427      0.500         0.25
# ...                   ...        ...        ...          ...
# 507330                 11   0.122160        NaN         0.00
# 507331                 15   0.123409      0.250         0.00
# 507332                 10   0.161195      0.000         0.00
# 507333                 11   0.248843      0.375         0.25
# 507334                 12   0.329156      0.625         0.25
#
#         normalization_comment  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 507330                      *
# 507331                    NaN
# 507332                    NaN
# 507333                    NaN
# 507334                    NaN
#
#                                   ingredient_food_kg_urls  \
# 0       ['http://idea.rpi.edu/heals/kb/ingredientname/...
# 1       ['http://idea.rpi.edu/heals/kb/ingredientname/...
# 2       ['http://idea.rpi.edu/heals/kb/ingredientname/...
# 3       ['http://idea.rpi.edu/heals/kb/ingredientname/...
# 4       ['http://idea.rpi.edu/heals/kb/ingredientname/...
# ...                                                   ...
# 507330                                                NaN
# 507331                                                NaN
# 507332                                                NaN
# 507333                                                NaN
# 507334                                                NaN
#
#                                  ingredient_food_kg_names
# 0       ['baking soda', 'brown sugar', 'butter', 'corn...
# 1       ['avocado', 'cilantro', 'cooked shrimp', 'garl...
# 2       ['cold water', 'condensed milk', 'cornflour', ...
# 3       ['dried mint flakes', 'dried oregano', 'dried ...
# 4       ['carrots', 'egg', 'fine dry breadcrumbs', 'ga...
# ...                                                   ...
# 507330                                                NaN
# 507331                                                NaN
# 507332                                                NaN
# 507333                                                NaN
# 507334                                                NaN
#
# [507335 rows x 37 columns]

# %%
dataframe.head()
# Out:
#    Unnamed: 0  recipe_id                           title  \
# 0           0     447642   Cranberry-Orange Caramel Corn
# 1           1      53662           Cocktail De Camarones
# 2           2     520465  Inbal Jerusalem Hotel Snowball
# 3           3     213601   Santorini Roasted Leg of Lamb
# 4           4      67731       Cantonese Chicken Burgers
#
#                                          description   author_id  duration  \
# 0  Taken from Beter Homes and Gardens, November 2...      409184      40.0
# 1  I ordered shrimp cocktail at a Mexican restaur...       64251      20.0
# 2  This recipe was created in response to a Janua...  1803632771     210.0
# 3  A succulent slow-roasted leg of lamb with herb...      183057     375.0
# 4  Adapted from a recipe in BHG's grilling magazine.       37779      38.0
#
#                                           directions  \
# 0  ['Preheat oven to 275 degrees. In a very large...
# 1  ['After you chop the tomatoes, onions and cila...
# 2  ['Combine gelatin with cold water', 'Combine c...
# 3  ['Trim excess fat and silver skin from lamb le...
# 4  ['In a mixing bowl, add the egg, sesame oil, a...
#
#                                          ingredients serves last_changed_date  \
# 0  {'': [('popcorn, popped', '12  time(s) cups ')...     20        2011-01-29
# 1  {'': [('shelled and cooked shrimp (50-60 count...    2-4        2009-06-03
# 2  {'': [('cream', '200  time(s) g '), ('vanilla ...      5        2015-01-08
# 3  {'': [('of lamb', '6  time(s) lbs leg '), ('dr...  10-12        2009-05-17
# 4  {'': [('egg, beaten', '1  time(s) '), ('toaste...      4        2007-11-21
#
#    ... sugars [g] protein [g] direction_size  ingredients_sizes  who_score  \
# 0  ...        6.9         0.8              9                  9   0.168254
# 1  ...        6.3        51.3              7                 10   0.335455
# 2  ...       78.0        87.7             12                 17   0.128082
# 3  ...        3.6        51.1              8                  8   0.320622
# 4  ...        4.2        30.3              6                 12   0.254427
#
#    fsa_score  nutri_score  normalization_comment  \
# 0      0.000         0.00                    NaN
# 1      0.625         0.25                    NaN
# 2      0.000         0.00                    NaN
# 3      0.375         0.00                    NaN
# 4      0.500         0.25                    NaN
#
#                              ingredient_food_kg_urls  \
# 0  ['http://idea.rpi.edu/heals/kb/ingredientname/...
# 1  ['http://idea.rpi.edu/heals/kb/ingredientname/...
# 2  ['http://idea.rpi.edu/heals/kb/ingredientname/...
# 3  ['http://idea.rpi.edu/heals/kb/ingredientname/...
# 4  ['http://idea.rpi.edu/heals/kb/ingredientname/...
#
#                             ingredient_food_kg_names
# 0  ['baking soda', 'brown sugar', 'butter', 'corn...
# 1  ['avocado', 'cilantro', 'cooked shrimp', 'garl...
# 2  ['cold water', 'condensed milk', 'cornflour', ...
# 3  ['dried mint flakes', 'dried oregano', 'dried ...
# 4  ['carrots', 'egg', 'fine dry breadcrumbs', 'ga...
#
# [5 rows x 37 columns]

# %% [markdown]
# Il dataset presenta 507335 che sono decisamente maggiori del dataset precedente di circa 50000

# %%
num_rows = dataframe.shape[0]
print(f"Number of rows in the CSV file: {num_rows}")
# Out:
# Number of rows in the CSV file: 507335

# %% [markdown]
# # Columns

# %% [markdown]
# Il dataset presenta un totale di 37 colonne, ma di queste quelle che ritenute più importanti da noi sono:
#   - recipe_id
#   - title
#   - ingredients
#   - tags
#   - calories [cal]
#   - caloriesFromFat [cal]
#   - totalFat [g]
#   - saturatedFat [g]
#   - cholesterol [mg]
#   - sodium [mg]
#   - totalCarbohydrate [g]
#   - dietaryFiber [g]
#   - sugars [g]
#   - protein [g]
#   - who_score ->  A recipe healthiness score based on WHO methodology. The range is 0-14, with 14 as the best.
#   - fsa_score ->  A recipe healthiness score based on the UK Food Standards Agency (FSA) nutrient profiling system. The range is 0-8, with 8 as the best.
#   - nutri_score ->  A recipe nutri-score. A is the best result, E is the worst result.

# %%
print("Column names in the CSV file:")
print(dataframe.columns.tolist())
# Out:
# Column names in the CSV file:
# ['Unnamed: 0', 'recipe_id', 'title', 'description', 'author_id', 'duration', 'directions', 'ingredients', 'serves', 'last_changed_date', 'food_kg_locator', 'recipe_url', 'tags', 'new_recipe_id', 'new_author_id', 'average_rating', 'number_of_ratings', 'servingsPerRecipe', 'servingSize [g]', 'calories [cal]', 'caloriesFromFat [cal]', 'totalFat [g]', 'saturatedFat [g]', 'cholesterol [mg]', 'sodium [mg]', 'totalCarbohydrate [g]', 'dietaryFiber [g]', 'sugars [g]', 'protein [g]', 'direction_size', 'ingredients_sizes', 'who_score', 'fsa_score', 'nutri_score', 'normalization_comment', 'ingredient_food_kg_urls', 'ingredient_food_kg_names']

# %%
print(len(dataframe.columns.tolist()))
# Out:
# 37

# %% [markdown]
# # Tags

# %% [markdown]
# Il dataset presenta un totale di 902 tags, ma quelli ritenuti da noi più importanti sono:
#   - Main dish = 71285
#   - Desserts = 42807
#   - Breakfast = 13384
#   - Appetizers = 20187
#   - Vegetables = 53485
#   - Meat = 50740
#   - Seafood = 14722
#   - Vegetarian = 35599
#   - Fruit = 31245
#   - Pasta rice and grains = 23924
#   - Chicken = 20304
#   - Pork = 12664
#
# Nel nostro transformer utilizzeremo solo le ricette che hanno un tag non nullo, che sono 230649

# %%
filtered_df = dataframe[dataframe['tags'].notna()]
len(filtered_df)
# Out:
# 230649

# %%
unique_tags = set()

for t in filtered_df['tags']:
  unique_tags.update(t.split(','))

print(unique_tags)
# Out:
# {" 'colombian']", " 'novelty']", " 'high-protein'", " 'smoker'", " 'eggs']", " 'british-columbian']", " 'healthy-2'", " 'infant-baby-friendly']", " 'steaks']", " 'quick-breads']", " 'taste-mood']", " 'potatoes'", " 'small-appliance'", " 'appetizers']", " 'peruvian']", " 'welsh']", " 'preparation'", "['dietary']", " 'spinach'", " 'mardi-gras-carnival']", " 'chutneys'", " 'scones'", " 'palestinian'", " 'congolese'", " 'venezuelan']", " 'high-in-something'", " 'ragu-recipe-contest']", " 'orange-roughy'", " 'baked-beans']", " 'beef-barley-soup']", " 'copycat'", " 'heirloom-historical'", " 'seasonal']", " 'served-cold'", " 'vegan'", " 'namibian'", " 'april-fools-day'", " 'easter'", " 'greens']", " 'bacon'", " 'finnish']", " 'portuguese'", " 'very-low-carbs'", " 'chick-peas-garbanzos'", " 'garnishes']", " 'quick-breads'", " 'crab'", " 'peruvian'", " 'mushrooms'", " 'punch'", " 'cookies-and-brownies']", " 'copycat']", " 'perch'", " 'clams']", " 'eggs-breakfast']", " 'low-sodium'", " 'baja'", " 'octopus']", " 'somalian'", " 'saltwater-fish'", " 'savory-sauces'", " 'ontario'", " 'pheasant'", " 'macaroni-and-cheese'", " 'chinese-new-year']", " 'desserts'", " 'marinades-and-rubs'", " 'argentine'", " 'indonesian']", " 'picnic'", " 'breads'", " 'crawfish']", " 'st-patricks-day'", " 'pot-roast']", " 'bass']", " 'english']", " 'canning'", " 'orange-roughy']", " 'chinese']", " 'irish-st-patricks-day']", " 'british-columbian'", " 'strawberries'", "['cuisine'", " 'hunan'", " 'savory'", "['']", " 'north-american'", " 'moose'", " 'vietnamese'", " 'korean']", " 'high-in-something']", " 'steaks'", " '4-hours-or-less']", " '3-steps-or-less']", " 'angolan'", " 'caribbean'", " 'trout'", " 'blueberries']", " 'fudge'", " 'poultry'", " 'bisques-cream-soups'", " 'chicken-stew']", " 'beans-side-dishes'", " 'elbow-macaroni'", " 'grilling']", " 'scandinavian'", " 'cakes']", "['Throw the ultimate fiesta with this sopaipillas recipe from Food.com.']", " 'unprocessed-freezer']", " 'iranian-persian']", " 'mixer'", " 'salads'", " 'cocktails'", " 'pork-ribs']", " 'christmas'", " 'wedding']", " 'potluck'", " 'rosh-hashanah'", " 'low-in-something']", " 'cooking-mixes']", " 'avocado']", " 'midwestern']", " 'pacific-northwest']", " 'bread-machine'", " 'chowders'", " 'dinner-party']", " 'dinner-party'", " 'spaghetti'", " 'thanksgiving']", " 'occasion'", " 'lettuces']", " 'frozen-desserts']", " 'middle-eastern']", " 'cauliflower']", " 'fall'", " 'beef-sausage']", " 'chard']", " 'squash']", " 'coconut']", " 'pressure-canning'", " 'puddings-and-mousses'", " 'chocolate']", " 'dietary']", " 'roast-beef'", " '1-day-or-more'", " 'cantonese'", " 'belgian']", " 'ecuadorean'", " 'brunch']", " 'beef-ribs']", " 'crawfish'", " 'rolls-biscuits']", " '15-minutes-or-less'", " 'steak']", " 'bananas']", " 'pies-and-tarts'", " 'szechuan'", " 'ham'", " 'omelets-and-frittatas'", " 'salad-dressings']", " 'cherries'", " 'pork-sausage']", " 'snacks']", " 'czech'", " 'pies'", " 'refrigerator'", " 'irish']", " 'rolled-cookies'", " 'mussels'", " 'short-grain-rice'", " 'chocolate'", " 'condiments-etc'", " 'oatmeal']", " 'roast-beef']", " 'rosh-hashana'", " 'duck-breasts'", " 'brown-bag'", " 'saltwater-fish']", " 'polynesian']", " 'grains'", " 'plums']", " 'mango']", " 'nut-free']", "['celebrity'", " 'sweet'", " 'spanish'", " 'nut-free'", " 'lebanese']", " 'yeast']", " 'no-cook'", " 'main-dish-pork'", " 'inexpensive']", " 'dairy-free']", " 'punch']", " 'english'", " 'shellfish']", " 'side-dishes'", " 'grapes']", " 'swiss'", "['30-minutes-or-less'", " 'asparagus'", " 'mothers-day'", " 'oamc-freezer-make-ahead'", " 'grilling'", " 'pheasant']", " 'long-grain-rice'", " 'brunch'", "['time-to-make'", " 'mushrooms']", " 'sole-and-flounder'", " 'african'", " 'pork-loin'", " 'mahi-mahi'", " 'turkey-breasts']", " 'steak'", " 'lime'", " 'chocolate-chip-cookies'", " 'peaches'", " 'leftovers']", " 'wedding'", " 'blueberries'", " 'pears'", " 'egyptian'", " 'marinades-and-rubs']", " 'shrimp-main-dish']", " 'pine ...

# %% [markdown]
# Ci sono 902 tags utilizzabili

# %%
print(len(unique_tags))
# Out:
# 902

# %%
from collections import Counter

tag_counts = Counter()

for tags in dataframe['tags'].dropna():
    tag_counts.update(tags.split(','))  # Change the delimiter if it's different

sorted_tag_counts = sorted(tag_counts.items(), key=lambda x: x[1], reverse=True)

print("Tags sorted by frequency:")
for tag, count in sorted_tag_counts:
    print(f"{tag}: {count}")
# Out:
# Tags sorted by frequency:
#  'preparation': 228901
#  'course': 212237
#  'time-to-make': 183953
#  'main-ingredient': 169696
#  'dietary': 160917
#  'easy': 124963
#  'occasion': 113779
#  'cuisine': 90880
#  'low-in-something': 76872
#  'main-dish': 71285
# ['60-minutes-or-less': 63815
#  'vegetables': 53485
#  'meat': 50740
# ['30-minutes-or-less': 50157
#  'equipment': 48551
#  'north-american': 48352
#  '4-hours-or-less']: 47853
#  'taste-mood': 47257
#  'low-sodium': 43228
#  'desserts': 42807
#  'low-carb': 42034
# ['15-minutes-or-less': 40876
# ['time-to-make': 40430
#  'healthy': 40204
#  'dinner-party': 37440
#  'low-cholesterol': 36617
#  'low-calorie': 36308
#  'vegetarian': 35599
#  '3-steps-or-less']: 35411
#  'beginner-cook': 35397
#  '5-ingredients-or-less': 35366
#  'holiday-event': 34759
#  'low-protein': 32384
#  'inexpensive': 31782
#  'low-saturated-fat': 31275
#  'fruit': 31245
#  'oven': 31140
#  'american': 31073
#  'number-of-servings': 30263
#  'eggs-dairy': 30075
#  'number-of-servings']: 28423
#  'kid-friendly': 27039
#  'side-dishes': 26714
#  'healthy-2': 26554
#  'comfort-food': 26089
#  'european': 24733
#  'poultry': 24075
#  'pasta-rice-and-grains': 23924
#  'lunch': 23688
#  'for-1-or-2': 22923
#  'low-fat': 22088
#  'stove-top': 22055
#  'equipment']: 21767
#  'seasonal': 21413
#  'presentation': 21156
#  'chicken': 20304
#  'appetizers': 20187
# ['weeknight': 19935
#  'for-large-groups': 17334
#  'beef': 17020
#  'one-dish-meal': 16466
#  'to-go': 16326
#  'brunch': 15717
#  'cheese': 14951
#  'seafood': 14722
#  'salads': 14489
#  'breads': 14426
#  'breakfast': 13384
#  'asian': 13380
#  'pasta': 12875
#  'pork': 12664
#  'condiments-etc': 11767
#  'cookies-and-brownies': 11742
#  'free-of-something': 11276
#  'soups-stews': 11206
#  'beverages': 11034
#  'high-in-something': 10813
#  'potluck': 10686
#  'potatoes': 10271
#  'summer': 10021
#  'vegan': 9998
#  'beans': 9484
#  'technique']: 9454
#  '3-steps-or-less': 9351
#  'cakes': 9251
#  'sweet': 9176
#  'very-low-carbs': 9155
#  'savory': 9127
#  'chocolate': 9116
#  'low-in-something']: 8602
#  'eggs': 8461
#  'spicy': 8205
#  'ground-beef': 8063
#  'christmas': 7895
#  'picnic': 7788
#  'fall': 7736
#  'winter': 7635
#  'italian': 7317
#  'fish': 7311
#  'high-protein': 7179
#  'served-hot']: 7101
#  'small-appliance': 7079
#  'southern-united-states': 7075
#  'snacks': 7068
#  'nuts': 6956
#  'gifts': 6745
#  'mexican': 6600
#  'crock-pot-slow-cooker': 6596
#  'diabetic': 6448
#  'finger-food': 6447
#  'casseroles': 6437
#  'chicken-breasts': 6411
#  'no-cook': 6182
#  'rice': 6003
#  'grains': 5987
#  '60-minutes-or-less': 5878
#  'gluten-free': 5732
#  'berries': 5644
#  'sandwiches': 5526
#  'sauces': 5513
#  'tropical-fruit': 5279
#  'shellfish': 5271
#  'romantic': 5173
#  'meat']: 5127
# ['course': 5078
#  'egg-free': 5061
#  'quick-breads': 5010
#  'served-hot': 4945
#  'high-calcium': 4872
#  'food-processor-blender': 4832
#  'refrigerator': 4820
#  'onions': 4817
#  'taste-mood']: 4797
#  'tomatoes': 4742
#  'pies-and-tarts': 4739
#  '30-minutes-or-less': 4702
#  'dips': 4605
#  'served-cold': 4603
#  'heirloom-historical': 4563
#  'canadian': 4560
#  'kosher': 4438
#  'apples': 4361
#  'toddler-friendly': 4293
#  'saltwater-fish': 4250
#  'shrimp': 4247
#  'thanksgiving': 4244
#  'cocktails': 4229
#  'oamc-freezer-make-ahead': 4209
#  'barbecue': 4106
#  'spring': 4064
# ['lactose': 4028
#  'citrus': 3994
#  'south-west-pacific': 3932
#  'greens': 3832
#  'novelty': 3699
#  'dietary']: 3645
#  'southwestern-united-states': 3521
#  'presentation']: 3281
#  'bar-cookies': 3255
#  'brunch']: 3179
#  'brown-bag': 3167
#  'mushrooms': 3138
#  'pasta-rice-and-grains']: 3096
#  'pies': 3077
#  'squash': 3061
#  'yeast': 3006
#  'drop-cookies': 3006
#  'served-cold']: 2947
#  '15-minutes-or-less': 2882
#  'midwestern': 2835
#  'australian': 2828
#  'african': 2826
#  'peppers': 2761
#  'grilling': 2756
#  'indian': 2662
#  'muffins': 2645
#  'valentines-day': 2634
#  'from-scratch']: 2585
#  'turkey': 2552
#  'northeastern-united-states': 2498
#  'carrots': 2486
#  'new-years': 2476
#  'puddings-and-mousses': 2424
#  'greek': 2385
#  'easter': 2356
#  'independence-day': 2344
#  'candy': 2326
#  'salad-dressings': 2301
#  'pancakes-and-waffles': 2268
#  'french': 2266
#  'spreads': 2262
#  'salmon': 2242
#  'to-go']: 2171
#  'microwave': 2129
#  'copycat': 2098
#  '1-day-or-more': 2095
#  'pineapple': 2076
#  'middle-eastern': 2047
#  'technique': 2042
#  'grilling']: 2012
#  'corn': 2008
#  'chinese': 1978
#  'strawberries': 1964
#  'savory-sauces': 1931
#  'bananas': 1904
#  'frozen-desserts': 1899
#  'hand-formed-cookies': 1889
#  'broil': 1864
#  'smoothies': 1864
#  'rolls-biscuits': 1821
#  'broccoli': 1808
#  'central-american': 1804
#  'bisques-cream-soups': 1800
#  'pitted-fruit': 1798
#  'pork-sausage': 1787
#  'superbowl': 1748
#  'english': 1725
#  'chicken-breasts']: 1719
# ['bacon': 1702
#  'caribbean': 1699
#  'stir-fry': 1688
#  'chili': 1657
#  'shellfish']: 1648
# ['ham': 1596
#  'stews': 1578
#  'freezer': 1572
#  'lemon': 1567
#  'tuna': 1546
#  'coconut': 1537
#  'spinach': 1533
#  'lamb-sheep': 1524
#  'yams-sweet-potatoes': 1505
#  'tex-mex': 1466
#  'black-beans': 1458
#  'savory-pies': 1442
# ['curries': 1437
#  'cheesecake': 1431
#  'small-appliance']: 1425
#  'pizza': 1421
#  'savory']: 1405
#  '4-hours-or-less': 1404
#  'crab': 1395
#  'chicken-thighs-legs': 1383
#  'german': 1376
#  'sweet']: 1348
#  'oranges': 1347
#  'mixer': 1338
#  'camping': 1293
#  'scandinavian': 1293
#  'omelets-and-frittatas': 1282
#  'blueberries': 1278
#  'pork-chops': 1262
#  'spaghetti': 1251
#  'bread-machine': 1241
#  'south-american': 1229
#  'cake-fillings-and-frostings': 1223
#  'elbow-macaroni': 1212
#  'marinades-and-rubs': 1207
#  'cajun': 1200
#  'cobblers-and-crisps': 1196
#  'thai': 1185
#  'lentils': 1169
#  'roast': 1157
#  'soy-tofu': 1131
#  'roast-beef': 1124
#  'chick-peas-garbanzos': 1120
#  'granola-and-porridge': 1103
#  'asparagus': 1103
#  'deep-fry': 1101
#  'spanish': 1071
#  'green-yellow-beans': 1035
#  'wedding': 1030
#  'canning': 1011
#  'chowders': 1007
#  'long-grain-rice': 999
#  'weeknight': 979
#  'cooking-mixes': 977
#  'coffee-cakes': 959
#  'raspberries': 957
#  'punch': 956
#  'pork-loins': 949
#  'tomatoes']: 946
#  'whole-chicken': 945
#  'freshwater-fish': 934
#  'saltwater-fish']: 934
#  'brownies': 913
#  'white-rice': 899
#  'moroccan': 889
#  'pacific-northwest': 881
#  'rolled-cookies': 866
#  'lasagna': 865
#  'cupcakes': 862
#  'steaks': 858
#  'cauliflower': 845
#  'creole': 841
#  'japanese': 834
#  'steak': 828
#  'penne': 821
#  'sweet-sauces': 821
#  'jams-and-preserves': 820
#  'californian': 809
#  'st-patricks-day': 807
#  'inexpensive']: 785
#  'lettuces': 775
#  'peaches': 774
#  'shakes': 770
#  'easy']: 753
#  'novelty']: 727
#  'ontario': 726
#  'scottish': 711
#  'herb-and-spice-mixes': 693
#  'fudge': 678
#  'hanukkah': 664
#  'salsas': 663
#  'cookies-and-brownies']: 660
#  'gelatin': 657
#  'halloween': 655
#  'irish': 649
#  'scones': 635
#  'quick-breads']: 631
#  'squash']: 629
#  'british-columbian': 627
#  'flat-shapes': 625
# ['celebrity': 624
#  'new-zealand': 620
#  'pears': 618
#  'lime': 618
#  'mango': 615
#  'melons': 615
#  'scallops': 614
#  'jewish-ashkenazi': 612
#  'brown-rice': 608
#  'high-in-something']: 591
#  'stuffings-dressings': 588
#  'clear-soups': 583
#  'preparation']: 581
#  'apples']: 576
#  'wild-game': 544
#  'wings': 536
#  'free-of-something']: 509
#  'ravioli-tortellini': 506
#  'pork-ribs': 490
#  'garnishes': 483
#  'seasonal']: 475
#  'onions']: 473
#  'cherries': 468
#  'tarts': 454
#  'hawaiian': 439
#  'asparagus']: 439
#  'steam': 431
#  'broccoli']: 422
#  'carrots']: 420
#  'passover': 419
#  'corn']: 419
#  'peppers']: 415
#  'polish': 404
#  'infant-baby-friendly': 403
#  'pasta-shells': 401
#  'spaghetti']: 401
#  'rosh-hashana': 390
#  'russian': 377
#  'stocks': 376
#  'beef-sausage': 373
#  'mixer']: 373
#  'swiss': 363
#  'cakes']: 358
#  'spinach']: 357
#  'swedish': 357
#  'green-yellow-beans']: 357
#  'portuguese': 348
#  'vietnamese': 337
#  'crusts-pastry-dough-2': 336
#  'elbow-macaroni']: 336
#  'veal': 330
#  'pork-chops']: 328
#  'south-african': 323
#  'one-dish-meal']: 322
#  'hungarian': 316
#  'mardi-gras-carnival': 310
#  'high-fiber': 309
#  'pressure-cooker': 308
#  'cod': 308
# ['main-ingredient': 305
#  'cauliflower']: 303
#  'lebanese': 300
#  'biscotti': 294
#  'main-dish']: 292
#  'leftovers']: 289
#  'sandwiches']: 280
#  'turkish': 279
#  'simply-potatoes']: 276
#  'ramadan': 276
#  'penne']: 272
#  'camping']: 268
#  'short-grain-rice': 265
#  'strawberries']: 260
#  'kwanzaa': 259
#  'deer': 257
#  'cuban': 253
#  'non-alcoholic']: 252
#  'iranian-persian': 250
#  'korean': 250
#  'chocolate']: 249
#  'brazilian': 247
#  'turkey-breasts': 245
#  'pork-loins']: 241
#  'long-grain-rice']: 239
#  'clams': 234
#  'tilapia': 233
#  'grapes': 231
#  'christmas']: 230
#  'halibut': 230
# ['danish': 228
#  'water-bath']: 226
#  'chicken-thighs-legs']: 222
#  'dutch': 219
#  'beef-ribs': 218
#  'indonesian': 217
#  'vegetables']: 215
#  'amish-mennonite': 214
#  'steaks']: 213
#  'soul']: 210
#  'mussels': 209
#  'super-bowl': 205
#  'pork-sausage']: 203
#  'greens']: 200
#  'filipino': 199
#  'polynesian': 197
#  'lobster': 197
#  'egyptian': 196
#  'pineapple']: 195
#  'gumbo': 195
#  'welsh': 194
#  'chutneys': 194
#  'dairy-free']: 194
#  'desserts']: 193
#  'steak']: 193
#  'breakfast']: 191
#  'norwegian': 190
#  'ravioli-tortellini']: 189
#  'bananas']: 188
#  'sole-and-flounder': 185
#  'jewish-sephardi': 184
#  'coconut']: 184
#  'quebec': 184
#  'white-rice']: 182
#  'baking']: 180
#  'jellies': 178
# ['oysters': 178
#  'berries']: 177
#  'finnish': 168
#  'water-bath': 168
#  'gifts']: 168
#  'mushrooms']: 165
#  'austrian': 162
#  'belgian': 162
#  'duck': 159
#  'cheese']: 158
#  'catfish': 158
#  'native-american': 158
#  'pennsylvania-dutch': 157
#  'peanut-butter']: 155
#  'zucchini']: 154
#  'salads']: 153
#  'baja': 152
#  'papaya': 152
#  'burgers']: 152
#  'smoker': 150
#  'no-shell-fish': 150
#  'toddler-friendly']: 147
#  'blueberries']: 147
#  'beef-organ-meats': 144
#  'plums': 143
#  'whole-turkey': 138
#  'lemon']: 135
#  'birthday']: 135
#  'tilapia']: 135
#  'manicotti': 133
#  'sourdough': 132
#  'pakistani': 132
#  'side-dishes']: 131
#  'czech': 131
#  'lettuces']: 129
#  'fish']: 129
#  'bar-cookies']: 127
#  'kiwifruit': 127
#  'burgers': 125
#  'european']: 123
#  'oranges']: 120
#  'malaysian': 119
#  'argentine': 119
#  'beginner-cook']: 119
#  'yeast']: 117
#  'superbowl']: 117
#  'from-scratch': 116
#  'pies']: 115
#  'szechuan': 114
#  'nut-free']: 112
#  'peruvian': 111
#  'soy-tofu']: 111
#  'soups-stews']: 110
# ['']: 109
#  'whole-chicken']: 107
#  'collard-greens': 106
#  'hidden-valley-ranch']: 106
#  'appetizers']: 106
#  'nut-free': 106
#  'dips']: 105
#  'baking': 105
#  'chard': 104
#  'puerto-rican': 104
#  'saudi-arabian': 102
#  'brown-rice']: 102
# ['preparation': 102
#  'eggs']: 101
#  'peaches']: 98
#  'iraqi': 97
#  'wings']: 96
#  'trout': 96
#  'thanksgiving']: 95
#  'cod']: 94
#  'clams']: 93
#  'birthday': 93
#  'palestinian': 92
#  'savory-sauces']: 92
#  'beef-liver': 91
#  'medium-grain-rice': 90
#  'meatloaf']: 90
#  'cantonese': 90
#  'pears']: 89
#  'pasta-shells']: 89
#  'avocado']: 87
#  'rolls-biscuits']: 86
#  'bok-choys': 86
#  'roast-beef']: 85
#  'ethiopian': 85
#  'cake-fillings-and-frostings']: 81
#  'raspberries']: 81
#  'halibut']: 80
#  'nuts']: 78
#  'cheesecake']: 78
#  'eggplant']: 74
#  'mahi-mahi': 74
#  'crawfish': 74
#  'lentils']: 73
#  'oaxacan': 72
#  'chilean': 72
#  'squid': 71
#  'italian']: 70
#  'salad-dressings']: 70
#  'reynolds-wrap']: 70
#  'lactose': 70
#  'mashed-potatoes']: 69
#  'bass': 69
#  'chicken-livers': 68
#  'pizza']: 68
#  'ham': 67
#  'orange-roughy': 66
#  'dinner-party']: 66
#  'meatballs']: 65
#  'breads']: 64
#  'colombian': 64
#  'holiday-event']: 63
#  'cherries']: 63
#  'asian']: 63
#  'northeastern-united-states']: 63
#  'snacks']: 61
#  'melons']: 61
#  'tempeh': 61
#  'chick-peas-garbanzos']: 61
#  'short-grain-rice']: 60
#  'whitefish': 60
#  'brownies']: 60
#  'black-beans']: 60
#  'sole-and-flounder']: 59
#  'coffee-cakes']: 57
#  'citrus']: 57
#  'puddings-and-mousses']: 56
#  'rabbit': 54
#  'cocktails']: 54
#  'pumpkin']: 54
#  'brewing']: 54
#  'nepalese': 53
#  'mexican']: 53
#  'frozen-desserts']: 52
#  'labor-day']: 52
#  'chocolate-chip-cookies']: 52
#  'ice-cream']: 51
#  'turkey-burgers']: 51
#  'mango']: 50
#  'cinco-de-mayo']: 50
#  'whole-turkey']: 50
#  'non-alcoholic': 49
#  'macaroni-and-cheese']: 49
#  'peanut-butter': 48
#  'cambodian': 46
#  'costa-rican': 46
#  'rosh-hashanah': 46
#  'micro-melanesia': 46
#  'midwestern']: 45
#  'venezuelan': 45
#  'icelandic': 44
#  'tropical-fruit']: 43
#  'ragu-recipe-contest']: 43
#  'valentines-day']: 42
#  'crusts-pastry-dough-2']: 42
#  'indian']: 41
#  'condiments-etc']: 41
#  'lunch']: 41
#  'a1-sauce']: 41
#  'chard']: 40
#  'libyan': 40
#  'whole-duck': 39
#  'turkey-breasts']: 39
#  'pheasant': 39
#  'oatmeal']: 39
#  'candy']: 38
#  'pitted-fruit']: 38
#  'duck-breasts': 38
#  'nigerian': 38
#  'bacon': 38
#  'college']: 37
#  'pork-ribs']: 37
#  'memorial-day': 35
#  'ecuadorean': 35
#  'beverages']: 35
#  'unprocessed-freezer']: 34
#  'guatemalan': 34
#  'elk': 34
#  'halloween']: 34
#  'mahi-mahi']: 33
#  'lime']: 33
#  'mashed-potatoes': 32
#  'dehydrator': 32
#  'artichoke']: 32
#  'hunan': 31
#  'veggie-burgers']: 31
#  'catfish']: 31
#  '1-day-or-more']: 31
#  'trout']: 31
#  'pumpkin': 30
#  'beans']: 29
#  'zucchini': 29
#  'kwanzaa']: 29
#  'mothers-day': 28
#  'cooking-mixes']: 28
#  'sweet-sauces']: 28
#  'mardi-gras-carnival']: 28
#  'chowders']: 28
#  'plums']: 27
#  'medium-grain-rice']: 27
#  'chili']: 27
#  'meatballs': 26
#  'fruit']: 26
#  'beef-sausage']: 25
#  'marinades-and-rubs']: 25
#  'new-zealand']: 25
#  'spreads']: 25
#  'beef-ribs']: 25
#  'meatloaf': 24
#  'pressure-canning': 23
#  'avocado': 23
#  'southern-united-states']: 23
#  'dehydrator']: 23
#  'chinese']: 23
#  'eggplant': 22
#  'south-american']: 22
#  'mothers-day']: 21
#  'honduran': 21
#  'manicotti']: 21
#  'fillings-and-frostings-chocolate']: 21
#  'pot-pie']: 21
#  'crawfish']: 20
#  'macaroni-and-cheese': 19
#  'papaya']: 19
#  'perch': 19
#  'garnishes']: 19
#  'american']: 19
#  'thai']: 18
#  'beijing': 18
#  'goose': 18
#  'squid']: 18
#  'bok-choys']: 18
#  'quail': 18
#  'st-patricks-day']: 18
#  'pressure-canning']: 18
#  'moose': 18
#  'georgian': 17
#  'english']: 17
#  'african']: 17
#  'collard-greens']: 17
#  'passover']: 17
#  'seafood']: 17
#  'fathers-day']: 16
#  'unprocessed-freezer': 16
#  'wedding']: 16
#  'swedish']: 16
#  'laotian': 16
#  'oamc-freezer-make-ahead']: 15
#  'memorial-day']: 15
#  'australian']: 15
#  'freshwater-fish']: 15
#  'chicken-livers']: 15
#  'duck-breasts']: 15
#  'sudanese': 15
# ['cuisine': 15
#  'quiche']: 15
#  'punch']: 15
# ['dietary': 15
#  'sugar-cookies']: 15
#  'stocks']: 15
#  'orange-roughy']: 14
#  'kiwifruit']: 14
#  'biscotti']: 14
#  'angolan': 13
#  'creole']: 13
#  'grapes']: 13
#  'halloween-cupcakes']: 13
#  'cinco-de-mayo': 13
#  'ice-cream': 13
#  'bass']: 13
#  'chocolate-chip-cookies': 13
#  'mongolian': 13
#  'whitefish']: 12
#  'copycat']: 12
#  'swiss']: 12
#  'vietnamese']: 11
#  'congolese': 11
#  'dips-lunch-snacks']: 11
#  'super-bowl']: 11
#  'octopus': 10
#  'quiche': 10
#  'shakes']: 10
#  'duck']: 10
#  'leftovers': 10
#  'veggie-burgers': 10
#  'stews']: 10
#  'halloween-cakes']: 10
#  'fathers-day': 9
#  'hanukkah']: 9
#  'somalian': 9
#  'smoothies']: 9
#  'middle-eastern']: 9
#  'peruvian']: 9
#  'pakistani']: 9
#  'colombian']: 9
#  'tempeh']: 8
#  'norwegian']: 8
#  'independence-day']: 8
#  'pasta-elbow-macaroni']: 8
#  'new-years']: 8
#  'salsas']: 8
#  'japanese']: 8
#  'californian']: 8
#  'portuguese']: 8
#  'artichoke': 8
#  'canadian']: 8
#  'oatmeal': 8
#  'chinese-new-year']: 7
#  'southwestern-united-states']: 7
#  'central-american']: 7
#  'easter']: 7
#  'eggs-dairy']: 7
#  'welsh']: 7
#  'pheasant']: 7
#  'perch']: 6
#  'british-columbian']: 6
#  'april-fools-day']: 6
#  'moroccan']: 6
#  'pennsylvania-dutch']: 6
#  'tex-mex']: 6
#  'beef-kidney': 6
#  'polynesian']: 6
#  'brewing': 6
#  'simply-potatoes2']: 6
#  'native-american']: 6
#  'sugar-cookies': 6
#  'no-shell-fish']: 6
#  'bear': 6
#  'namibian': 6
#  'pot-pie': 6
#  'lebanese']: 6
#  'turkey-burgers': 5
#  'ontario']: 5
#  'czech']: 5
#  'prepared-potatoes']: 5
#  'baja']: 5
#  'whole-duck']: 5
#  'irish']: 5
#  'pickeral': 5
#  '60-minutes-or-less']: 5
# ['occasion': 5
#  'scones']: 5
# ['low-protein': 5
#  'chilean']: 4
#  'egyptian']: 4
#  'halloween-cocktails']: 4
#  'octopus']: 4
#  'pacific-northwest']: 4
#  'dutch']: 4
#  'caribbean']: 4
#  'rosh-hashana']: 4
#  'russian']: 4
#  'chinese-new-year': 4
#  'rabbit']: 4
#  'belgian']: 3
#  'main-dish-beef': 3
#  'quebec']: 3
#  'scottish']: 3
#  'austrian']: 3
#  'main-dish-pork': 3
#  'celebrity': 3
#  'micro-melanesia']: 3
#  'argentine']: 3
#  'hawaiian']: 3
#  'moose']: 3
#  'polish']: 3
# ['healthy': 3
#  'heirloom-historical']: 3
#  'venezuelan']: 3
#  'ramadan']: 3
#  'finnish']: 3
#  'pickeral']: 2
#  'iranian-persian']: 2
#  'side-dishes-beans': 2
#  'korean']: 2
#  'heirloom-historical-recipes': 2
#  'cuban']: 2
# ['number-of-servings': 2
#  'pasta-salad']: 2
#  'costa-rican']: 2
#  'crock-pot-main-dish']: 2
#  'ecuadorean']: 2
#  'main-dish-chicken': 2
#  'filipino']: 2
#  'main-dish-pork']: 2
#  'turkish']: 2
#  'danish': 2
#  'roast-beef-main-dish': 1
#  'roast-beef-comfort-food']: 1
#  'breakfast-eggs': 1
#  'eggs-breakfast']: 1
#  'mushroom-soup': 1
#  'beef-barley-soup']: 1
#  'breakfast-casseroles': 1
#  'breakfast-potatoes': 1
#  'breakfast-eggs']: 1
#  'pork-loin': 1
#  'cranberry-sauce']: 1
#  'beans-side-dishes']: 1
#  'beef-sauces': 1
#  'spaghetti-sauce']: 1
#  'pasta-rice-and-grains-elbow-macaroni']: 1
#  'goose']: 1
#  'main-dish-chicken']: 1
#  'snacks-kid-friendly': 1
#  'snacks-sweet']: 1
#  'for-large-groups']: 1
#  'infant-baby-friendly']: 1
#  'main-dish-pasta': 1
# ['less_thansql:name_topics_of_recipegreater_than']: 1
#  'main-dish-seafood': 1
#  'shrimp-main-dish']: 1
#  'labor-day': 1
#  'pasta-elbow-macaroni': 1
# ['dietary']: 1
#  'chicken-stews': 1
#  'chicken-stew']: 1
#  'black-bean-soup': 1
#  'bean-soup']: 1
#  'indonesian']: 1
#  'rosh-hashanah']: 1
# ['Throw the ultimate fiesta with this sopaipillas recipe from Food.com.']: 1
#  'healthy']: 1
#  'chicken-crock-pot']: 1
#  'pork-crock-pot': 1
# ['chicken']: 1
#  'served-hot-new-years': 1
#  'ham-and-bean-soup']: 1
#  'halloween-cakes': 1
#  'high-in-something-diabetic-friendly']: 1
#  'irish-st-patricks-day']: 1
#  'beans-side-dishes': 1
#  'baked-beans']: 1
#  'april-fools-day': 1
#  'dips-summer']: 1
#  'middle-eastern-main-dish']: 1
#  'lamb-sheep-main-dish']: 1
#  'cabbage']: 1
#  'desserts-fruit': 1
#  'desserts-easy']: 1
#  'for-large-groups-holiday-event']: 1
#  'stews-poultry']: 1
#  'lasagne']: 1
#  'spaghetti-sauce': 1
#  'marinara-sauce']: 1
#  'pork-loins-roast']: 1
#  'occasion']: 1
#  'beef-crock-pot': 1
#  'pot-roast']: 1
#  'pumpkin-bread': 1
#  'bread-pudding']: 1

# %% [markdown]
# # Ingredients

# %%
dataframe['ingredients'][0]
# Out:
# "{'': [('popcorn, popped', '12  time(s) cups '), ('dried cranberries', '1  time(s) cup '), ('whole almond', '0.5 time(s) cup '), ('butter', '0.5 time(s) cup '), ('brown sugar, packed', '0.5 time(s) cup '), ('corn syrup (light color)', '0.25 time(s) cup '), ('orange juice', '2  time(s) tablespoons '), ('vanilla', '2  time(s) teaspoons '), ('baking soda', '0.5 time(s) teaspoon ')]}"

# %%
data = {'': [('popcorn, popped', '12  time(s) cups '), ('dried cranberries', '1  time(s) cup '), ('whole almond', '0.5 time(s) cup '), ('butter', '0.5 time(s) cup '), ('brown sugar, packed', '0.5 time(s) cup '), ('corn syrup (light color)', '0.25 time(s) cup '), ('orange juice', '2  time(s) tablespoons '), ('vanilla', '2  time(s) teaspoons '), ('baking soda', '0.5 time(s) teaspoon ')]}

first_words = [item[0].split(',')[0] if ',' in item[0] else item[0] for item in data['']]
print(first_words)
# Out:
# ['popcorn', 'dried cranberries', 'whole almond', 'butter', 'brown sugar', 'corn syrup (light color)', 'orange juice', 'vanilla', 'baking soda']

# %% [markdown]
# # Healthiness Score

# %%
dataframe['nutri_score']
# Out:
# 0         0.00
# 1         0.25
# 2         0.00
# 3         0.00
# 4         0.25
#           ...
# 507330    0.00
# 507331    0.00
# 507332    0.00
# 507333    0.25
# 507334    0.25
# Name: nutri_score, Length: 507335, dtype: float64

# %%
dataframe['who_score']
# Out:
# 0         0.168254
# 1         0.335455
# 2         0.128082
# 3         0.320622
# 4         0.254427
#             ...
# 507330    0.122160
# 507331    0.123409
# 507332    0.161195
# 507333    0.248843
# 507334    0.329156
# Name: who_score, Length: 507335, dtype: float64

# %%
dataframe['fsa_score']
# Out:
# 0         0.000
# 1         0.625
# 2         0.000
# 3         0.375
# 4         0.500
#           ...
# 507330      NaN
# 507331    0.250
# 507332    0.000
# 507333    0.375
# 507334    0.625
# Name: fsa_score, Length: 507335, dtype: float64
